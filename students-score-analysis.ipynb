# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/student-grade-prediction/student-mat.csv

# %%
df=pd.read_csv('/kaggle/input/student-grade-prediction/student-mat.csv')

# %%
df.head(10)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1     GP   F   17       U     GT3       T     1     1   at_home     other
# 2     GP   F   15       U     LE3       T     1     1   at_home     other
# 3     GP   F   15       U     GT3       T     4     2    health  services
# 4     GP   F   16       U     GT3       T     3     3     other     other
# 5     GP   M   16       U     LE3       T     4     3  services     other
# 6     GP   M   16       U     LE3       T     2     2     other     other
# 7     GP   F   17       U     GT3       A     4     4     other   teacher
# 8     GP   M   15       U     LE3       A     3     2  services     other
# 9     GP   M   15       U     GT3       T     3     4     other     other
#
#    ... internet romantic  famrel  freetime  goout Dalc Walc health absences  \
# 0  ...       no       no       4         3      4    1    1      3        6
# 1  ...      yes       no       5         3      3    1    1      3        4
# 2  ...      yes       no       4         3      2    2    3      3       10
# 3  ...      yes      yes       3         2      2    1    1      5        2
# 4  ...       no       no       4         3      2    1    2      5        4
# 5  ...      yes       no       5         4      2    1    2      5       10
# 6  ...      yes       no       4         4      4    1    1      3        0
# 7  ...       no       no       4         1      4    1    1      1        6
# 8  ...      yes       no       4         2      2    1    1      1        0
# 9  ...      yes       no       5         5      1    1    1      5        0
#
#   average_grade
# 0      5.666667
# 1      5.333333
# 2      8.333333
# 3     14.666667
# 4      8.666667
# 5     15.000000
# 6     11.666667
# 7      5.666667
# 8     17.666667
# 9     14.666667
#
# [10 rows x 31 columns]

# %%
df.shape
# Out:
# (395, 31)

# %%
df.isnull().sum() #It has zero null values
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#lets make one grade for all the students by taking the mean of all three grades
df['average_grade']=(df['G1']+df['G2']+df['G3'])/3

# %%
df=df.drop(['G1','G2','G3'],axis=1)

# %%
df.head(5)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   internet romantic  famrel  freetime  goout Dalc Walc health absences  \
# 0       no       no       4         3      4    1    1      3        6
# 1      yes       no       5         3      3    1    1      3        4
# 2      yes       no       4         3      2    2    3      3       10
# 3      yes      yes       3         2      2    1    1      5        2
# 4       no       no       4         3      2    1    2      5        4
#
#   average_grade
# 0      5.666667
# 1      5.333333
# 2      8.333333
# 3     14.666667
# 4      8.666667
#
# [5 rows x 31 columns]

# %% [markdown]
# Here we are going to plot school vs average grade so we will use bar plot

# %%
sns.barplot(x=df['school'],y=df['average_grade'],data=df)

# %%
#here we can see that school doesnt play any significant role in the marks of student

# %%
sns.barplot(x=df['sex'],y=df['average_grade'],data=df)

# %%
#males are scoring little higher than females

# %%
sns.barplot(x=df['age'],y=df['average_grade'],data=df)

# %%
#students of age group 20 scores the highest

# %%
sns.barplot(x=df['address'],y=df['average_grade'],data=df)

# %%
#here also students of urban areas score slightly higher than of rular

# %%
sns.barplot(x=df['famsize'],y=df['average_grade'],data=df)

# %%
#students belonging to family size LE3 scores slightly higher

# %%
sns.barplot(x=df['Pstatus'],y=df['average_grade'],data=df)

# %%
sns.barplot(x=df['Fedu'],y=df['average_grade'],data=df)

# %%
sns.barplot(x=df['Medu'],y=df['average_grade'],data=df)

# %%
sns.barplot(x=df['Mjob'],y=df['average_grade'],data=df)

# %%
#students whose mothers are employed in health services scores higher as comparison to others

# %%
sns.barplot(x=df['Fjob'],y=df['average_grade'],data=df)

# %%
#in this scenario students whose fathers are teachers gets higher marks

# %%
sns.barplot(x=df['studytime'],y=df['average_grade'],data=df)

# %%
#student who studies for 3 to 4 hrs per day scores higher marks

# %%
#lets observe how many students study for 3 to 4 hrs
sns.countplot(x=df['studytime'])

# %%
#maximum students study for 2 hrs daily and only few students study for 3 to 4 hrs daily

# %%
sns.countplot(df['failures'])

# %%
#we can observe that only a few people are failed in 1 or 2 subjects

# %%
sns.barplot(x=df['activities'],y=df['average_grade'],data=df)

# %%
#no much difference there in grades based on the activities

# %%
sns.barplot(x=df['romantic'],y=df['average_grade'],data=df)

# %%
#well thats  the thing we  younsters are aware and i guess this doesnt require any explanation

# %%
sns.barplot(x=df['health'],y=df['average_grade'],data=df)

# %%
#this is quite obvious better health would always results in good scores

# %%
sns.countplot(x=df['health'],hue=df['sex'],data=df)

# %%
sns.barplot(x=df['freetime'],y=df['average_grade'],data=df)

# %%
#from this observation we can conclude that free time is also important for our studies,students having free time of 2 hrs scores maximum grades

# %%
sns.barplot(x=df['internet'],y=df['average_grade'],data=df)

# %%
#students who have to access to internet scores higher than those who havent

# %%
#now we have to deal with the categorical features
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for i in list(df.columns):
    df[i]=le.fit_transform(df[i])

# %%
df.head(5)
# Out:
#    school  sex  age  address  famsize  Pstatus  Medu  Fedu  Mjob  Fjob  ...  \
# 0       0    0    3        1        0        0     4     4     0     4  ...
# 1       0    0    2        1        0        1     1     1     0     2  ...
# 2       0    0    0        1        1        1     1     1     0     2  ...
# 3       0    0    0        1        0        1     4     2     1     3  ...
# 4       0    0    1        1        0        1     3     3     2     2  ...
#
#    internet  romantic  famrel  freetime  goout  Dalc  Walc  health  absences  \
# 0         0         0       3         2      3     0     0       2         6
# 1         1         0       4         2      2     0     0       2         4
# 2         1         0       3         2      1     1     2       2        10
# 3         1         1       2         1      1     0     0       4         2
# 4         0         0       3         2      1     0     1       4         4
#
#    average_grade
# 0             13
# 1             12
# 2             21
# 3             40
# 4             22
#
# [5 rows x 31 columns]

# %%
y=df['average_grade']
x=df.drop(['average_grade'],axis=1)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=0,test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
list_models=[]
list_scores=[]
list_errors=[]
lr=LinearRegression()
lr.fit(x_train,y_train)
pred_1=lr.predict(x_test)
score_1=r2_score(y_test,pred_1)
error_1=mean_squared_error(y_test,pred_1)
list_models.append('linear regression')
list_scores.append(score_1)
list_errors.append(error_1)

# %%
from sklearn.ensemble import RandomForestRegressor
rfg=RandomForestRegressor()
rfg.fit(x_train,y_train)
pred_2=rfg.predict(x_test)
score_2=r2_score(y_test,pred_2)
error_2=mean_squared_error(y_test,pred_2)
list_models.append('randomforest')
list_scores.append(score_2)
list_errors.append(error_2)

# %%
from sklearn.svm import SVR
svm=SVR()
svm.fit(x_train,y_train)
pred_3=svm.predict(x_test)
score_3=r2_score(y_test,pred_3)
error_3=mean_squared_error(y_test,pred_3)
list_models.append('svr')
list_scores.append(score_3)
list_errors.append(error_3)

# %%
score_3
# Out:
# 0.09307176134446438

# %%
from xgboost import  XGBRegressor
xgb=XGBRegressor()
xgb.fit(x_train,y_train)
pred_4=xgb.predict(x_test)
score_4=r2_score(y_test,pred_4)
error_4=mean_squared_error(y_test,pred_4)
list_models.append('xgb regressor')
list_scores.append(score_4)
list_errors.append(error_4)

# %%
plt.figure(figsize=(12,5))
plt.bar(list_models,list_errors,width=0.3)
plt.xlabel('regressors')
plt.ylabel('mean squared error')
plt.show()

# %%
plt.figure(figsize=(12,5))
plt.bar(list_models,list_scores,width=0.3)
plt.xlabel('regressors')
plt.ylabel('r2 score')
plt.show()
